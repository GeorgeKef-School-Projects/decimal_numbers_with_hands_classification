# %% [markdown]
# ## Άσκηση 1
#
#
# Από το dataset το οποίο δίνεται προσπαθούμε να ξεχωρίσουμε νούμερα που απεικονίζονται σε φωτογραφίας με τη βοήθεια ενός Απλού Νευρωνικού Δικτύου. Στο συγκεκριμένο dataset έχουμε 10 κλάσεις μία για κάθε ένα δεκαδικό νούμερο από το 0 έως και το 9. Το dataset αποτελείται από 2062 εικόνες οι οποίες έχουν μέγεθος 100x100 και είναι στη RGB μορφή άρα είναι με την μορφή 100x100x3 πινάκων.

# %% [markdown]
# Αρχικά εισάγουμε τις βιβλιοθήκες τις οποίες θα
# χρειαστούμε, οι οποίες αποτελούνται κυρίως από αυτές που χρειάζονται για την επεξεργασία των δεδομένων μας(numpy,listdir), για την απεικόνιση γραφημάτων και αποτελεσμάτων καθώς επίσης και για το Νευρωνικό Δύκτιο.

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
#import libs 
import array
from os import listdir
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Στη συνέχεια, έχοντας εισάγει τις απαραίτητες βιβλιοθήκες, εισάγουμε τα δεδομένα του dataset από τον αντίστοιχο φάκελο που τα έχουμε ανεβάσει στο drive. Επιπλέον, για κάθε ένα από αυτά δημιουργούμε και έναν

# %%
data = np.array([])
data_y = np.array([])

# %%
for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/0'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/0/' + filename)
    data = np.append(data,img_data) 
    data_y = np.append(data_y,[0])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/1'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/1/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[1])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/2'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/2/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[2])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/3'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/3/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[3])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/4'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/4/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[4])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/5'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/5/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[5])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/6'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/6/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[6])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/7'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/7/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[7])

for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/8'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/8/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[8])
    
for filename in listdir('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/9'):
    img_data = image.imread('/content/drive/MyDrive/Giorgos/Σχολή/9ο Εξάμηνο /Αναγνώριση Προτύπων/Εργασίες /Τελική Εργασία/Dataset/9/' + filename)
    data = np.append(data,img_data)
    data_y = np.append(data_y,[9])

# %% [markdown]
# Αφού εισάγουμε και τα δεδομένα μας, τότε τα επεξεργαζόμαστε ώστε να τα φέρουμε στη μορφή την οποία τα θέλουμε. Δηλαδή στη μορφή πινάκων, καθώς τα εισάγαμε σε λίστες πράγμα που δεν μας επιτρέπει την περαιτέρω επεξεργασία τους με ευκολία. Έπειτα, κάνουμε κανονικοποίηση των δεδομένων μας καθώς αυτά παίρνουν τιμές από 0 έως 255.

# %%
#Store Training Data
x_train = data.reshape(len(data_y),100,100,3)

y_train = data_y

print(x_train.dtype)
print(x_train.shape)
print(y_train.shape)

#print(x_train[0])
# Out:
# float64
# (2059, 100, 100, 3)
# (2059,)

# %%
#Mix Training data 

#x_train_mix = np.array([])
#y_train_mix = np.array([])

#for i in range(0,len(y_train),3):
#  x_train_mix = np.append(x_train[i],x_train_mix)
#  y_train_mix = np.append(y_train[i],y_train_mix)

#for i in range(0,len(y_train),4):
#  x_train_mix = np.append(x_train[i],x_train_mix)
#  y_train_mix = np.append(y_train[i],y_train_mix)

#for i in range(0,len(y_train),10):
#  x_train_mix = np.append(x_train[i],x_train_mix)
#  y_train_mix = np.append(y_train[i],y_train_mix)

#for i in range(0,len(y_train),5):
#  x_train_mix = np.append(x_train[i],x_train_mix)
#  y_train_mix = np.append(y_train[i],y_train_mix)

#x_train = np.asarray(x_train_mix)
#x_train = x_train.reshape(len(y_train_mix),100,100,3)

#print(x_train.dtype)
#print(x_train.shape)
#print(y_train.shape)

#y_train = np.asarray(y_train_mix)
#print(y_train.shape)
#print(y_train)

# %%
#Store Testing data
x_test = np.array([])
y_test = np.array([])

for i in range(0,len(y_train),4):
  x_test = np.append(x_train[i],x_test)
  y_test = np.append(y_train[i],y_test)

x_test = x_test.reshape(len(y_test),100,100,3)

print(x_test.dtype)
print(x_test.shape)
print(y_test.shape)
# Out:
# float64
# (515, 100, 100, 3)
# (515,)

# %%
#Normilization
x_train /= 255.
x_test /= 255.

#Number of Classes
num_classes = 10

# %%
#Visualization of the first train object 
plt.figure()
plt.imshow(x_train[150])
plt.grid(False)
plt.show()

# %% [markdown]
# ## Ερώτημα α)

# %%
model_a = keras.Sequential([
    keras.layers.Flatten(input_shape=( 100, 100, 3)),
    keras.layers.Dense(256),
    keras.layers.Dense(128),
    keras.layers.Dense(10, activation='softmax')
])

#Summary of the Neural Network
model_a.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_4 (Flatten)          (None, 30000)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               7680256
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                1290
# ...
# Total params: 7,714,442
# Trainable params: 7,714,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
Sequences = np.asarray(x_train)
Targets   = np.asarray(y_train)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))

Sequences = np.expand_dims(Sequences, -1)
Targets   = np.expand_dims(Targets, -1)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))
# Out:
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3)
# Targets:   (2059,)
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3, 1)
# Targets:   (2059, 1)

# %%
#Compilation of the model
model_a.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
tf.convert_to_tensor(x_train)
# Out:
# <tf.Tensor: shape=(2059, 100, 100, 3), dtype=float64, numpy=
# array([[[[0.4745098 , 0.46666667, 0.47058824],
#          [0.48627451, 0.47843137, 0.48235294],
#          [0.49019608, 0.48235294, 0.48627451],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.48235294, 0.4745098 , 0.47843137],
#          [0.49411765, 0.48627451, 0.49019608],
#          [0.49803922, 0.49019608, 0.49411765],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.49411765, 0.48627451, 0.49019608],
#          [0.50196078, 0.49411765, 0.49803922],
#          [0.50588235, 0.49803922, 0.50196078],
#          ...,
#          [0.47058824, 0.45490196, 0.44313725],
#          [0.4627451 , 0.44705882, 0.43529412],
#          [0.45882353, 0.44313725, 0.43137255]],
# ...

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

num_epochs = 30
history = model_a.fit(x_train, y_train, epochs = num_epochs, callbacks=[earlystopping],validation_split=0.,batch_size=32,verbose=1)
# Out:
# Epoch 1/30
# 65/65 [==============================] - 1s 5ms/step - loss: 125.8482 - accuracy: 0.1030
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/30
# 65/65 [==============================] - 0s 5ms/step - loss: 12.4125 - accuracy: 0.2837
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/30
# 65/65 [==============================] - 0s 5ms/step - loss: 4.1057 - accuracy: 0.4618
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/30
# 65/65 [==============================] - 0s 4ms/step - loss: 3.5268 - accuracy: 0.4960
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/30
# ...

# %%
train_loss = history.history['loss']
#val_loss = history.history['val_loss']
plt.plot(range(30), train_loss, 'g', label='Training loss')
#plt.plot(range(30), val_loss, 'b', label='Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

train_acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
plt.plot(range(30), train_acc, 'g', label='Training accuracy')
#plt.plot(range(30), val_acc, 'b', label='validation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
score = model_a.evaluate(x_test,  y_test)

print('\nScore', score)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3365 - accuracy: 0.8932
#
# Score [0.3365277051925659, 0.893203854560852]

# %% [markdown]
# ## Ερώτημα c)

# %%
model_c = keras.Sequential([
    keras.layers.Flatten(input_shape=( 100, 100, 3)),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

#Summary of the Neural Network
model_c.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_5 (Flatten)          (None, 30000)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               7680256
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                1290
# ...
# Total params: 7,714,442
# Trainable params: 7,714,442
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compilation of the model
model_c.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
tf.convert_to_tensor(x_train)
# Out:
# <tf.Tensor: shape=(2059, 100, 100, 3), dtype=float64, numpy=
# array([[[[0.4745098 , 0.46666667, 0.47058824],
#          [0.48627451, 0.47843137, 0.48235294],
#          [0.49019608, 0.48235294, 0.48627451],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.48235294, 0.4745098 , 0.47843137],
#          [0.49411765, 0.48627451, 0.49019608],
#          [0.49803922, 0.49019608, 0.49411765],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.49411765, 0.48627451, 0.49019608],
#          [0.50196078, 0.49411765, 0.49803922],
#          [0.50588235, 0.49803922, 0.50196078],
#          ...,
#          [0.47058824, 0.45490196, 0.44313725],
#          [0.4627451 , 0.44705882, 0.43529412],
#          [0.45882353, 0.44313725, 0.43137255]],
# ...

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

num_epochs = 30
history = model_c.fit(x_train, y_train, epochs = num_epochs, callbacks=[earlystopping],validation_split=0.,batch_size=32,verbose=1)
# Out:
# Epoch 1/30
# 65/65 [==============================] - 1s 5ms/step - loss: 10.4552 - accuracy: 0.1096
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/30
# 65/65 [==============================] - 0s 5ms/step - loss: 2.2144 - accuracy: 0.2796
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/30
# 65/65 [==============================] - 0s 4ms/step - loss: 1.8017 - accuracy: 0.3750
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/30
# 65/65 [==============================] - 0s 5ms/step - loss: 1.7639 - accuracy: 0.4374
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/30
# ...

# %%
train_loss = history.history['loss']
#val_loss = history.history['val_loss']
plt.plot(range(30), train_loss, 'g', label='Training loss')
#plt.plot(range(30), val_loss, 'b', label='Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

train_acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
plt.plot(range(30), train_acc, 'g', label='Training accuracy')
#plt.plot(range(30), val_acc, 'b', label='validation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
score = model_c.evaluate(x_test,  y_test)

print('\nScore:', score)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4328 - accuracy: 0.8641
#
# Score: [0.43281805515289307, 0.8640776872634888]

# %% [markdown]
# ## Ερώτημα d)

# %%
model_d = keras.Sequential([
    keras.layers.Flatten(input_shape=( 100, 100, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation='softmax')
])

#Summary of the Neural Network
model_d.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_10 (Flatten)         (None, 30000)             0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 30000)             120000
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               7680256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# ...

# %%
#Compilation of the model
model_c.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
Sequences = np.asarray(x_train)
Targets   = np.asarray(y_train)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))

Sequences = np.expand_dims(Sequences, -1)
Targets   = np.expand_dims(Targets, -1)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))
# Out:
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3)
# Targets:   (2059,)
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3, 1)
# Targets:   (2059, 1)

# %%
tf.convert_to_tensor(x_train)
# Out:
# <tf.Tensor: shape=(2059, 100, 100, 3), dtype=float64, numpy=
# array([[[[0.4745098 , 0.46666667, 0.47058824],
#          [0.48627451, 0.47843137, 0.48235294],
#          [0.49019608, 0.48235294, 0.48627451],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.48235294, 0.4745098 , 0.47843137],
#          [0.49411765, 0.48627451, 0.49019608],
#          [0.49803922, 0.49019608, 0.49411765],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.49411765, 0.48627451, 0.49019608],
#          [0.50196078, 0.49411765, 0.49803922],
#          [0.50588235, 0.49803922, 0.50196078],
#          ...,
#          [0.47058824, 0.45490196, 0.44313725],
#          [0.4627451 , 0.44705882, 0.43529412],
#          [0.45882353, 0.44313725, 0.43137255]],
# ...

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

num_epochs = 30
history = model_c.fit(x_train, y_train, epochs = num_epochs, callbacks=[earlystopping],validation_split=0.0,batch_size=32,verbose=1)
# Out:
# Epoch 1/30
# 65/65 [==============================] - 1s 6ms/step - loss: 0.1079 - accuracy: 0.9646
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/30
# 65/65 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.9406
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/30
# 65/65 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9531
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/30
# 65/65 [==============================] - 0s 6ms/step - loss: 0.1406 - accuracy: 0.9490
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/30
# ...

# %%
train_loss = history.history['loss']
#val_loss = history.history['val_loss']
plt.plot(range(30), train_loss, 'g', label='Training loss')
#plt.plot(range(30), val_loss, 'b', label='Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

train_acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
plt.plot(range(30), train_acc, 'g', label='Training accuracy')
#plt.plot(range(30), val_acc, 'b', label='validation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model_c.evaluate(x_test,  y_test)

print('\nScore:', test_acc)
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
#
# Score: 1.0

# %% [markdown]
# ## Ερώτημα e)

# %%
model_e = keras.Sequential([
    keras.layers.Flatten(input_shape=( 100, 100, 3)),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.2),
    #keras.layers.BatchNormalization(),
    #keras.layers.Dense(128, activation='elu'),
    #keras.layers.Dropout(0.2),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation='softmax')
])

#Summary of the Neural Network
model_e.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_35 (Flatten)         (None, 30000)             0
# _________________________________________________________________
# batch_normalization_95 (Batc (None, 30000)             120000
# _________________________________________________________________
# dense_113 (Dense)            (None, 256)               7680256
# _________________________________________________________________
# dropout_66 (Dropout)         (None, 256)               0
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_114 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 256)               0
# ...

# %%
#Compilation of the model
model_e.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
Sequences = np.asarray(x_train)
Targets   = np.asarray(y_train)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))

Sequences = np.expand_dims(Sequences, -1)
Targets   = np.expand_dims(Targets, -1)
print("Expected: (num_samples, timesteps, channels)")
print("Sequences: {}".format(Sequences.shape))
print("Targets:   {}".format(Targets.shape))
# Out:
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3)
# Targets:   (2059,)
# Expected: (num_samples, timesteps, channels)
# Sequences: (2059, 100, 100, 3, 1)
# Targets:   (2059, 1)

# %%
tf.convert_to_tensor(x_train)
# Out:
# <tf.Tensor: shape=(2059, 100, 100, 3), dtype=float64, numpy=
# array([[[[0.4745098 , 0.46666667, 0.47058824],
#          [0.48627451, 0.47843137, 0.48235294],
#          [0.49019608, 0.48235294, 0.48627451],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.48235294, 0.4745098 , 0.47843137],
#          [0.49411765, 0.48627451, 0.49019608],
#          [0.49803922, 0.49019608, 0.49411765],
#          ...,
#          [0.46666667, 0.45098039, 0.43921569],
#          [0.45882353, 0.44313725, 0.43137255],
#          [0.45490196, 0.43921569, 0.42745098]],
#
#         [[0.49411765, 0.48627451, 0.49019608],
#          [0.50196078, 0.49411765, 0.49803922],
#          [0.50588235, 0.49803922, 0.50196078],
#          ...,
#          [0.47058824, 0.45490196, 0.44313725],
#          [0.4627451 , 0.44705882, 0.43529412],
#          [0.45882353, 0.44313725, 0.43137255]],
# ...

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)

num_epochs = 30
history = model_e.fit(x_train, y_train, epochs = num_epochs, callbacks=[earlystopping],validation_split=0.0,batch_size=32,verbose=1)
# Out:
# Epoch 1/30
# 65/65 [==============================] - 1s 6ms/step - loss: 2.2702 - accuracy: 0.2959
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 2/30
# 65/65 [==============================] - 0s 6ms/step - loss: 1.1824 - accuracy: 0.5995
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 3/30
# 65/65 [==============================] - 0s 6ms/step - loss: 0.7754 - accuracy: 0.7311
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 4/30
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6228 - accuracy: 0.7852
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# Epoch 5/30
# ...

# %%
train_loss = history.history['loss']
#val_loss = history.history['val_loss']
plt.plot(range(30), train_loss, 'g', label='Training loss')
#plt.plot(range(30), val_loss, 'b', label='Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

train_acc = history.history['accuracy']
#val_acc = history.history['val_accuracy']
plt.plot(range(30), train_acc, 'g', label='Training accuracy')
#plt.plot(range(30), val_acc, 'b', label='validation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_loss, test_acc = model_c.evaluate(x_test,  y_test)

print('\nTest accuracy:', test_acc)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
#
# Test accuracy: 1.0
